# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek01bv/Pandas/blob/main/Pandas_Mushroom_Dataset_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://datamites.com/resource/images/final/logo-1.png)

# %% [markdown]
# # Introduction
#
# This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family. Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one.
#
# ![](https://archive.ics.uci.edu/ml/assets/MLimages/Large73.jpg)
#
# The first column of the dataset signifies the edible or poisonous status of the mushroom and the description of rest of the columns is as
# 1. cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# 2. cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# 3. cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r, pink=p,purple=u,red=e,white=w,yellow=y
# 4. bruises?: bruises=t,no=f
# 5. odor: almond=a,anise=l,creosote=c,fishy=y,foul=f, musty=m,none=n,pungent=p,spicy=s
# 6. gill-attachment: attached=a,descending=d,free=f,notched=n
# 7. gill-spacing: close=c,crowded=w,distant=d
# 8. gill-size: broad=b,narrow=n
# 9. gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e, white=w,yellow=y
# 10. stalk-shape: enlarging=e,tapering=t
# 11. stalk-root: bulbous=b,club=c,cup=u,equal=e, rhizomorphs=z,rooted=r,missing=?
# 12. stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
# 13. stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
# 14. stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y
# 15. stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y
# 16. veil-type: partial=p,universal=u
# 17. veil-color: brown=n,orange=o,white=w,yellow=y
# 18. ring-number: none=n,one=o,two=t
# 19. ring-type: cobwebby=c,evanescent=e,flaring=f,large=l, none=n,pendant=p,sheathing=s,zone=z
# 20. spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r, orange=o,purple=u,white=w,yellow=y
# 21. population: abundant=a,clustered=c,numerous=n, scattered=s,several=v,solitary=y
# 22. habitat: grasses=g,leaves=l,meadows=m,paths=p, urban=u,waste=w,woods=d
#
# The dataset being used is available on [UCI datasets](https://archive.ics.uci.edu/ml/datasets/Mushroom)

# %% [markdown]
# # Solve the questions in this notebook starting from #1 and then solve the rest sequentially.

# %% [markdown]
# # 1
# Read the dataset from the url https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.data and display the first 5 rows

# %%
import pandas as pd
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.data')
df.head()
# Out:
#    p  x  s  n  t p.1  f  c n.1  k  ... s.2  w w.1 p.2 w.2  o p.3 k.1 s.3  u
# 0  e  x  s  y  t   a  f  c   b  k  ...   s  w   w   p   w  o   p   n   n  g
# 1  e  b  s  w  t   l  f  c   b  n  ...   s  w   w   p   w  o   p   n   n  m
# 2  p  x  y  w  t   p  f  c   n  n  ...   s  w   w   p   w  o   p   k   s  u
# 3  e  x  s  g  f   n  f  w   b  k  ...   s  w   w   p   w  o   e   n   a  g
# 4  e  x  y  y  t   a  f  c   b  n  ...   s  w   w   p   w  o   p   k   n  g
#
# [5 rows x 23 columns]

# %% [markdown]
# # 2
# Show the first 15 rows of the dataset

# %%
df.head(15)
# Out:
#     p  x  s  n  t p.1  f  c n.1  k  ... s.2  w w.1 p.2 w.2  o p.3 k.1 s.3  u
# 0   e  x  s  y  t   a  f  c   b  k  ...   s  w   w   p   w  o   p   n   n  g
# 1   e  b  s  w  t   l  f  c   b  n  ...   s  w   w   p   w  o   p   n   n  m
# 2   p  x  y  w  t   p  f  c   n  n  ...   s  w   w   p   w  o   p   k   s  u
# 3   e  x  s  g  f   n  f  w   b  k  ...   s  w   w   p   w  o   e   n   a  g
# 4   e  x  y  y  t   a  f  c   b  n  ...   s  w   w   p   w  o   p   k   n  g
# 5   e  b  s  w  t   a  f  c   b  g  ...   s  w   w   p   w  o   p   k   n  m
# 6   e  b  y  w  t   l  f  c   b  n  ...   s  w   w   p   w  o   p   n   s  m
# 7   p  x  y  w  t   p  f  c   n  p  ...   s  w   w   p   w  o   p   k   v  g
# 8   e  b  s  y  t   a  f  c   b  g  ...   s  w   w   p   w  o   p   k   s  m
# 9   e  x  y  y  t   l  f  c   b  g  ...   s  w   w   p   w  o   p   n   n  g
# 10  e  x  y  y  t   a  f  c   b  n  ...   s  w   w   p   w  o   p   k   s  m
# ...

# %% [markdown]
# # 3
# Display the last 5 rows of the dataset

# %%
df.tail()
# Out:
#       p  x  s  n  t p.1  f  c n.1  k  ... s.2  w w.1 p.2 w.2  o p.3 k.1 s.3  u
# 8118  e  k  s  n  f   n  a  c   b  y  ...   s  o   o   p   o  o   p   b   c  l
# 8119  e  x  s  n  f   n  a  c   b  y  ...   s  o   o   p   n  o   p   b   v  l
# 8120  e  f  s  n  f   n  a  c   b  n  ...   s  o   o   p   o  o   p   b   c  l
# 8121  p  k  y  n  f   y  f  c   n  b  ...   k  w   w   p   w  o   e   w   v  l
# 8122  e  x  s  n  f   n  a  c   b  y  ...   s  o   o   p   o  o   p   o   c  l
#
# [5 rows x 23 columns]

# %% [markdown]
# # 4
# Display the last 15 rows of the dataset

# %%
df.tail(15)
# Out:
#       p  x  s  n  t p.1  f  c n.1  k  ... s.2  w w.1 p.2 w.2  o p.3 k.1 s.3  u
# 8108  e  b  s  w  f   n  f  w   b  w  ...   s  w   w   p   w  t   p   w   n  g
# 8109  e  x  s  n  f   n  a  c   b  o  ...   s  o   o   p   o  o   p   n   v  l
# 8110  e  k  s  w  f   n  f  w   b  p  ...   s  w   w   p   w  t   p   w   n  g
# 8111  e  k  s  n  f   n  a  c   b  o  ...   s  o   o   p   n  o   p   b   v  l
# 8112  p  k  y  e  f   y  f  c   n  b  ...   k  p   p   p   w  o   e   w   v  d
# 8113  p  f  y  c  f   m  a  c   b  y  ...   y  c   c   p   w  n   n   w   c  d
# 8114  e  x  s  n  f   n  a  c   b  y  ...   s  o   o   p   o  o   p   o   v  l
# 8115  p  k  y  n  f   s  f  c   n  b  ...   k  p   w   p   w  o   e   w   v  l
# 8116  p  k  s  e  f   y  f  c   n  b  ...   s  p   w   p   w  o   e   w   v  d
# 8117  p  k  y  n  f   f  f  c   n  b  ...   s  p   w   p   w  o   e   w   v  d
# 8118  e  k  s  n  f   n  a  c   b  y  ...   s  o   o   p   o  o   p   b   c  l
# ...

# %% [markdown]
# # 5
# Display the column names

# %%
df.columns
# Out:
# Index(['p', 'x', 's', 'n', 't', 'p.1', 'f', 'c', 'n.1', 'k', 'e', 'e.1', 's.1',
#        's.2', 'w', 'w.1', 'p.2', 'w.2', 'o', 'p.3', 'k.1', 's.3', 'u'],
#       dtype='object')

# %% [markdown]
# # 6
# On reading the dataset https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.data the first row of the data has become the column names, import the dataset while mitigating this issue

# %%
dfdf = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.data', header = None)
df.head()
# Out:
#    p  x  s  n  t p.1  f  c n.1  k  ... s.2  w w.1 p.2 w.2  o p.3 k.1 s.3  u
# 0  e  x  s  y  t   a  f  c   b  k  ...   s  w   w   p   w  o   p   n   n  g
# 1  e  b  s  w  t   l  f  c   b  n  ...   s  w   w   p   w  o   p   n   n  m
# 2  p  x  y  w  t   p  f  c   n  n  ...   s  w   w   p   w  o   p   k   s  u
# 3  e  x  s  g  f   n  f  w   b  k  ...   s  w   w   p   w  o   e   n   a  g
# 4  e  x  y  y  t   a  f  c   b  n  ...   s  w   w   p   w  o   p   k   n  g
#
# [5 rows x 23 columns]

# %% [markdown]
# # 7
# In the dataset set the column names to
#
# [cat, cap-shape, cap-surface, cap-color, bruises, odor, gill-attachment, gill-spacing, gill-size, gill-color, stalk-shape, stalk-root, stalk-surface-above-ring, stalk-surface-below-ring, stalk-color-above-ring, stalk-color-below-ring, veil-type, veil-color, ring-number, ring-type, spore-print-color, population, habitat]

# %%
 column_names = [
    'cat', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
    'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape',
    'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring',
    'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type',
    'veil-color', 'ring-number', 'ring-type', 'spore-print-color',
    'population', 'habitat'
]
print(len(column_names))
df.columns = column_names[:len(df.columns)]

print(df)
# Out:
# 23
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      e         x           s         y       t    a               f
# 1      e         b           s         w       t    l               f
# 2      p         x           y         w       t    p               f
# 3      e         x           s         g       f    n               f
# 4      e         x           y         y       t    a               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 8118   e         k           s         n       f    n               a
# 8119   e         x           s         n       f    n               a
# 8120   e         f           s         n       f    n               a
# 8121   p         k           y         n       f    y               f
# 8122   e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 8
# What is the shape of the data

# %%
df.shape
# Out:
# (8123, 23)

# %% [markdown]
# # 9
# How many rows are present in this dataset?

# %%
df.shape[0]
# Out:
# 8123

# %% [markdown]
# # 10
# How many columns are present in the dataset?

# %%
df.shape[1]
# Out:
# 23

# %% [markdown]
# # 11
# What is the size of the dataset?

# %%
df.size
# Out:
# 186829

# %% [markdown]
# # 12
# Check the datatype of all the columns

# %%
df.dtypes
# Out:
# cat                         object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %% [markdown]
# # 13
# The column cat signifies the class of the mushroom i.e, if it's edible (e) or poisonous (p). How many edible and poisonous mushrooms are in this dataset?

# %%
df['cat'].value_counts()
# Out:
# cat
# e    4208
# p    3915
# Name: count, dtype: int64

# %% [markdown]
# # 14
# Select all the musrooms with cap-color of green (g)

# %%
df.loc[df['cap-color']=='g']
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 3      e         x           s         g       f    n               f
# 14     e         s           f         g       f    n               f
# 35     e         s           f         g       f    n               f
# 55     e         f           f         g       f    n               f
# 59     e         s           f         g       f    n               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 8054   e         b           f         g       f    n               f
# 8073   e         b           f         g       f    n               f
# 8077   e         b           f         g       f    n               f
# 8083   e         b           f         g       f    n               f
# 8093   e         b           s         g       f    n               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 15
# Find the number of mushrooms with habitat of urban (u)

# %%
df.loc[df['habitat']=='u']
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 2      p         x           y         w       t    p               f
# 12     p         x           y         w       t    p               f
# 14     e         s           f         g       f    n               f
# 17     p         x           y         w       t    p               f
# 18     p         x           s         n       t    p               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 5945   p         x           s         b       t    f               f
# 5974   p         x           s         b       t    f               f
# 5980   p         f           s         w       t    f               f
# 5987   p         f           s         w       t    f               f
# 5997   p         f           s         b       t    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 16
# Find all the unique values in ring-number

# %%
df['ring-number'].unique()
# Out:
# array(['o', 't', 'n'], dtype=object)

# %% [markdown]
# # 17
# Find the count of all unique values in ring-number

# %%
df.value_counts('ring-number')
# Out:
# ring-number
# o    7487
# t     600
# n      36
# Name: count, dtype: int64

# %% [markdown]
# # 18
# Select all the musrooms with cap-color of green (g) ot yellow (y)

# %%
df.loc[(df['cap-color']=='g') | (df['cap-color']=='y')]
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      e         x           s         y       t    a               f
# 3      e         x           s         g       f    n               f
# 4      e         x           y         y       t    a               f
# 8      e         b           s         y       t    a               f
# 9      e         x           y         y       t    l               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 8054   e         b           f         g       f    n               f
# 8073   e         b           f         g       f    n               f
# 8077   e         b           f         g       f    n               f
# 8083   e         b           f         g       f    n               f
# 8093   e         b           s         g       f    n               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 19
# Select all the musrooms with cap-color of green (g) and population on abundant (a)

# %%
df.loc[(df['cap-color']=='g') | (df['population']=='a')]
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 3      e         x           s         g       f    n               f
# 13     e         x           f         n       f    n               f
# 14     e         s           f         g       f    n               f
# 15     e         f           f         w       f    n               f
# 35     e         s           f         g       f    n               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 8054   e         b           f         g       f    n               f
# 8073   e         b           f         g       f    n               f
# 8077   e         b           f         g       f    n               f
# 8083   e         b           f         g       f    n               f
# 8093   e         b           s         g       f    n               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 20
# Select all the musrooms with ring-type of large=l and veil-type partial (p)  and stalk-root of bulbous (b)

# %%
df.loc[(df['ring-type']=='l') & (df['veil-type']=='p') & (df['stalk-root']=='b')]
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1815   p         x           f         g       f    f               f
# 2127   p         x           f         g       f    f               f
# 2177   p         x           f         g       f    f               f
# 2237   p         x           f         g       f    f               f
# 2384   p         x           f         g       f    f               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 5982   p         f           y         y       f    f               f
# 5985   p         f           y         y       f    f               f
# 5989   p         f           f         y       f    f               f
# 5992   p         f           y         y       f    f               f
# 5998   p         f           y         y       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 21
# Check the number of missing values in this dataset

# %%
df.isna().sum()
# Out:
# cat                         0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# # 22
# In this dataset, ? is present in stalk-root column signifying missing data, find such rows containing the ?

# %%
df.loc[df['stalk-root']=='?']
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 3983   e         x           y         b       t    n               f
# 4022   p         x           y         e       f    y               f
# 4075   e         f           y         u       f    n               f
# 4099   p         x           y         e       f    y               f
# 4103   p         x           y         n       f    f               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 8118   e         k           s         n       f    n               a
# 8119   e         x           s         n       f    n               a
# 8120   e         f           s         n       f    n               a
# 8121   p         k           y         n       f    y               f
# 8122   e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 23
# Clearly some missing data is present but is represented using ?. Replace ? with NaN

# %%
df.replace('?', pd.NA, inplace=True)
df.isnull().sum()
# Out:
# cat                            0
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  2480
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# dtype: int64

# %% [markdown]
# # 24
# Check for missing values again, it will be prominent that sometimes missing values are not visible by default and you will need to approach the data accordingly

# %%
df.isna().sum()
# Out:
# cat                            0
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  2480
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# dtype: int64

# %% [markdown]
# # 25
# Replace missing values with 10000 without making this change permanent

# %%
df.fillna(10000)
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      e         x           s         y       t    a               f
# 1      e         b           s         w       t    l               f
# 2      p         x           y         w       t    p               f
# 3      e         x           s         g       f    n               f
# 4      e         x           y         y       t    a               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 8118   e         k           s         n       f    n               a
# 8119   e         x           s         n       f    n               a
# 8120   e         f           s         n       f    n               a
# 8121   p         k           y         n       f    y               f
# 8122   e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 26
# Replace all the missing values with the mode without making this change permanent

# %%
df.fillna(df.mode().iloc[0])
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      e         x           s         y       t    a               f
# 1      e         b           s         w       t    l               f
# 2      p         x           y         w       t    p               f
# 3      e         x           s         g       f    n               f
# 4      e         x           y         y       t    a               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 8118   e         k           s         n       f    n               a
# 8119   e         x           s         n       f    n               a
# 8120   e         f           s         n       f    n               a
# 8121   p         k           y         n       f    y               f
# 8122   e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 27
# Replace all the missing values with mode without making this change permanent

# %%
df.fillna(df.mode().iloc[0])
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      e         x           s         y       t    a               f
# 1      e         b           s         w       t    l               f
# 2      p         x           y         w       t    p               f
# 3      e         x           s         g       f    n               f
# 4      e         x           y         y       t    a               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 8118   e         k           s         n       f    n               a
# 8119   e         x           s         n       f    n               a
# 8120   e         f           s         n       f    n               a
# 8121   p         k           y         n       f    y               f
# 8122   e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 28
# Sort this data is ascending alphabatical order according to cap-color

# %%
df.sort_values(by='cap-color')
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 5677   p         f           s         b       t    f               f
# 5284   e         x           s         b       t    n               f
# 5289   p         f           s         b       t    f               f
# 5905   e         x           s         b       t    n               f
# 5715   p         x           s         b       t    f               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 5418   p         f           y         y       f    f               f
# 3907   p         f           f         y       f    f               f
# 3908   p         f           f         y       f    f               f
# 5430   p         f           y         y       f    f               f
# 0      e         x           s         y       t    a               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 29
# Sort this data is descending alphabatical order according to cap-color

# %%
df.sort_values(by='cap-color', ascending=False)
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      e         x           s         y       t    a               f
# 770    e         b           s         y       t    l               f
# 777    e         x           s         y       t    l               f
# 4924   p         x           y         y       f    f               f
# 4923   p         x           f         y       f    f               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 5736   e         x           y         b       t    n               f
# 5738   p         f           s         b       t    f               f
# 5743   p         f           y         b       t    n               f
# 5503   e         x           y         b       t    n               f
# 5807   p         x           s         b       t    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 30
# Sort the data first according to cap-shape then cap-surface both ascending

# %%
df.sort_values(by=['cap-shape', 'cap-surface'])
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 4825   p         b           f         y       f    n               f
# 5130   p         b           f         y       f    n               f
# 5397   p         b           f         n       f    n               f
# 5954   p         b           f         n       f    n               f
# 6141   e         b           f         w       f    n               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 7972   p         x           y         e       f    f               f
# 8000   e         x           y         n       f    n               f
# 8004   p         x           y         e       f    s               f
# 8037   e         x           y         g       t    n               f
# 8094   p         x           y         c       f    m               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 31
# Sort the data first according to cap-shape then cap-surface then cap-color all ascending

# %%
df.sort_values(by=['cap-shape','cap-surface','cap-color' ])
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 6213   e         b           f         g       f    n               f
# 6659   e         b           f         g       f    n               f
# 6751   e         b           f         g       f    n               f
# 6923   e         b           f         g       f    n               f
# 7085   e         b           f         g       f    n               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 5692   p         x           y         y       f    f               f
# 5791   p         x           y         y       f    f               f
# 5799   p         x           y         y       f    n               f
# 5840   p         x           y         y       f    f               f
# 5957   p         x           y         y       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 32
# Sort the data first according to ascending cap-shape then descending cap-surface then ascending cap-color

# %%
df.sort_values(by='cap-shape')
df.sort_values(by='cap-surface', ascending=False)
df.sort_values(by='cap-color')
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 5677   p         f           s         b       t    f               f
# 5284   e         x           s         b       t    n               f
# 5289   p         f           s         b       t    f               f
# 5905   e         x           s         b       t    n               f
# 5715   p         x           s         b       t    f               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 5418   p         f           y         y       f    f               f
# 3907   p         f           f         y       f    f               f
# 3908   p         f           f         y       f    f               f
# 5430   p         f           y         y       f    f               f
# 0      e         x           s         y       t    a               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 33
# If you check the dataset, it does not seem to be in the sorted order, make this change permanent

# %%
df.sort_values(by=['cap-shape','cap-surface','cap-color' ], inplace=True)
df
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 6213   e         b           f         g       f    n               f
# 6659   e         b           f         g       f    n               f
# 6751   e         b           f         g       f    n               f
# 6923   e         b           f         g       f    n               f
# 7085   e         b           f         g       f    n               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 5692   p         x           y         y       f    f               f
# 5791   p         x           y         y       f    f               f
# 5799   p         x           y         y       f    n               f
# 5840   p         x           y         y       f    f               f
# 5957   p         x           y         y       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 34
# Now the indexes seem messed up, try to set indexes starting from zero without adding additional column without making permanent changes to df dataframe

# %%
df.reset_index(drop=True )
df
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      e         b           f         g       f    n               f
# 1      e         b           f         g       f    n               f
# 2      e         b           f         g       f    n               f
# 3      e         b           f         g       f    n               f
# 4      e         b           f         g       f    n               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 8118   p         x           y         y       f    f               f
# 8119   p         x           y         y       f    f               f
# 8120   p         x           y         y       f    n               f
# 8121   p         x           y         y       f    f               f
# 8122   p         x           y         y       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 35
# Now the indexes seem messed up, try to set indexes starting from zero without adding additional column while making permanent changes to df dataframe

# %%
df.reset_index(drop=True, inplace = True )
df
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      e         b           f         g       f    n               f
# 1      e         b           f         g       f    n               f
# 2      e         b           f         g       f    n               f
# 3      e         b           f         g       f    n               f
# 4      e         b           f         g       f    n               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 8118   p         x           y         y       f    f               f
# 8119   p         x           y         y       f    f               f
# 8120   p         x           y         y       f    n               f
# 8121   p         x           y         y       f    f               f
# 8122   p         x           y         y       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 36
# Select the cat column only without using loc or iloc

# %%
df['cat']

# %% [markdown]
# # 37
# Select the cat column and odor column without using iloc or loc

# %%
df['cat', 'odor']

# %% [markdown]
# # 39
# Select rows from index of 90 to 99 without using iloc or loc

# %%
df[90:100]
# Out:
#    cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 90   e         b           s         n       f    n               f
# 91   e         b           s         n       f    n               a
# 92   e         b           s         n       f    n               a
# 93   e         b           s         n       f    n               a
# 94   e         b           s         n       f    n               a
# 95   e         b           s         n       f    n               a
# 96   e         b           s         n       f    n               a
# 97   e         b           s         n       f    n               a
# 98   e         b           s         n       f    n               a
# 99   e         b           s         n       f    n               a
#
#    gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 90            c         b          w  ...                        y
# 91            c         b          n  ...                        s
# ...

# %% [markdown]
# # 40
# Select the first 5 rows of the dataset using iloc

# %%
df[0:5]
# Out:
#   cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0   e         b           f         g       f    n               f
# 1   e         b           f         g       f    n               f
# 2   e         b           f         g       f    n               f
# 3   e         b           f         g       f    n               f
# 4   e         b           f         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            w         b          p  ...                        s
# 1            w         b          p  ...                        k
# 2            w         b          w  ...                        s
# 3            w         b          p  ...                        k
# 4            w         b          w  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# # 41
# Select rows fron index 100 to 150 using iloc

# %%
df.iloc[100:151]
# Out:
#     cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 100   e         b           s         n       f    n               a
# 101   e         b           s         n       f    n               a
# 102   e         b           s         n       f    n               a
# 103   e         b           s         n       f    n               a
# 104   e         b           s         n       f    n               a
# 105   e         b           s         n       f    n               a
# 106   e         b           s         n       f    n               a
# 107   e         b           s         n       f    n               a
# 108   e         b           s         n       f    n               a
# 109   e         b           s         n       f    n               a
# 110   e         b           s         n       f    n               a
# 111   e         b           s         n       f    n               a
# 112   e         b           s         n       f    n               a
# ...

# %% [markdown]
# # 42
# Select the last 5 rows using iloc

# %%
df.iloc[-5:]
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8118   p         x           y         y       f    f               f
# 8119   p         x           y         y       f    f               f
# 8120   p         x           y         y       f    n               f
# 8121   p         x           y         y       f    f               f
# 8122   p         x           y         y       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8118            c         b          h  ...                        k
# 8119            c         b          h  ...                        k
# 8120            c         n          w  ...                        y
# 8121            c         b          g  ...                        k
# 8122            c         b          g  ...                        k
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %% [markdown]
# # 43
# Select row index from 100 to 105 and the first five columns using iloc

# %%
df.iloc[100:105, :5]
# Out:
#     cat cap-shape cap-surface cap-color bruises
# 100   e         b           s         n       f
# 101   e         b           s         n       f
# 102   e         b           s         n       f
# 103   e         b           s         n       f
# 104   e         b           s         n       f

# %% [markdown]
# # 44
# Select rows indexes from 90 to 95 and columns starting from cap-color to population

# %%
df.iloc[90:95, 3:-1]
# Out:
#    cap-color bruises odor gill-attachment gill-spacing gill-size gill-color  \
# 90         n       f    n               f            c         b          w
# 91         n       f    n               a            c         b          n
# 92         n       f    n               a            c         b          y
# 93         n       f    n               a            c         b          o
# 94         n       f    n               a            c         b          o
#
#    stalk-shape stalk-root stalk-surface-above-ring stalk-surface-below-ring  \
# 90           e          b                        y                        y
# 91           e       <NA>                        s                        s
# 92           e       <NA>                        s                        s
# 93           e       <NA>                        s                        s
# 94           e       <NA>                        s                        s
#
# ...

# %% [markdown]
# # 45
# Select last 5 rows and last 5 columns using iloc

# %%
df.iloc[-5:, -5:]
# Out:
#      ring-number ring-type spore-print-color population habitat
# 8118           o         l                 h          v       g
# 8119           o         l                 h          y       p
# 8120           o         e                 w          v       d
# 8121           o         l                 h          v       d
# 8122           o         l                 h          y       g

# %% [markdown]
# # 46
# Select all the rows but only first 2 columns using iloc

# %%
df.iloc[:, :2]
# Out:
#      cat cap-shape
# 0      e         b
# 1      e         b
# 2      e         b
# 3      e         b
# 4      e         b
# ...   ..       ...
# 8118   p         x
# 8119   p         x
# 8120   p         x
# 8121   p         x
# 8122   p         x
#
# [8123 rows x 2 columns]

# %% [markdown]
# # 47
# Select all the row indexes divisbile by 10 using iloc between row index of 100 to 200
#
# Hint: Use range as well

# %%
for i in range(100, 201, 10):
  print(df.iloc[i])
# Out:
# cat                            e
# cap-shape                      b
# cap-surface                    s
# cap-color                      n
# bruises                        f
# odor                           n
# gill-attachment                a
# gill-spacing                   c
# gill-size                      b
# gill-color                     o
# stalk-shape                    e
# stalk-root                  <NA>
# stalk-surface-above-ring       s
# stalk-surface-below-ring       s
# stalk-color-above-ring         o
# stalk-color-below-ring         o
# veil-type                      p
# veil-color                     n
# ring-number                    o
# ring-type                      p
# spore-print-color              n
# population                     c
# habitat                        l
# Name: 100, dtype: object
# cat                            e
# cap-shape                      b
# cap-surface                    s
# cap-color                      n
# ...

# %% [markdown]
# # 48
# Select rows 100 to 150 using loc

# %%
df.iloc[100:151]
# Out:
#     cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 100   e         b           s         n       f    n               a
# 101   e         b           s         n       f    n               a
# 102   e         b           s         n       f    n               a
# 103   e         b           s         n       f    n               a
# 104   e         b           s         n       f    n               a
# 105   e         b           s         n       f    n               a
# 106   e         b           s         n       f    n               a
# 107   e         b           s         n       f    n               a
# 108   e         b           s         n       f    n               a
# 109   e         b           s         n       f    n               a
# 110   e         b           s         n       f    n               a
# 111   e         b           s         n       f    n               a
# 112   e         b           s         n       f    n               a
# ...

# %% [markdown]
# # 49
# Select row 110, 125 and 190 using loc

# %%
df.iloc[110]
df.iloc[125]
df.iloc[190]
# Out:
# cat                         e
# cap-shape                   b
# cap-surface                 s
# cap-color                   w
# bruises                     t
# odor                        l
# gill-attachment             f
# gill-spacing                c
# gill-size                   b
# gill-color                  k
# stalk-shape                 e
# stalk-root                  c
# stalk-surface-above-ring    s
# stalk-surface-below-ring    s
# stalk-color-above-ring      w
# stalk-color-below-ring      w
# veil-type                   p
# veil-color                  w
# ring-number                 o
# ring-type                   p
# spore-print-color           k
# population                  n
# habitat                     g
# Name: 190, dtype: object

# %% [markdown]
# # 50
# Select all the musrooms with cat of edible (e) using loc

# %%
df.loc[df['cat']=='e']
# Out:
#      cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      e         b           f         g       f    n               f
# 1      e         b           f         g       f    n               f
# 2      e         b           f         g       f    n               f
# 3      e         b           f         g       f    n               f
# 4      e         b           f         g       f    n               f
# ...   ..       ...         ...       ...     ...  ...             ...
# 7954   e         x           y         y       t    a               f
# 7955   e         x           y         y       t    a               f
# 7956   e         x           y         y       t    a               f
# 7957   e         x           y         y       t    l               f
# 7958   e         x           y         y       t    a               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 51
# Select columns bruised and population using loc

# %%
df.loc[:, ['bruises','population']]
# Out:
#      bruises population
# 0          f          n
# 1          f          s
# 2          f          s
# 3          f          n
# 4          f          s
# ...      ...        ...
# 8118       f          v
# 8119       f          y
# 8120       f          v
# 8121       f          v
# 8122       f          y
#
# [8123 rows x 2 columns]

# %% [markdown]
# # 52
# Select rows 100, 125 and 150 and columns bruised and population using loc

# %%
df.iloc[[100,125,150],[3,-1]]
# Out:
#     cap-color habitat
# 100         n       l
# 125         n       l
# 150         w       m

# %% [markdown]
# # 53
# Select rows 100 to 110 and columns starting from odor to gill-color using loc

# %%
df.iloc[100:111,4:-1]
# Out:
#     bruises odor gill-attachment gill-spacing gill-size gill-color  \
# 100       f    n               a            c         b          o
# 101       f    n               a            c         b          o
# 102       f    n               a            c         b          n
# 103       f    n               a            c         b          o
# 104       f    n               a            c         b          y
# 105       f    n               a            c         b          n
# 106       f    n               a            c         b          n
# 107       f    n               a            c         b          o
# 108       f    n               a            c         b          y
# 109       f    n               a            c         b          y
# 110       f    n               a            c         b          n
#
#     stalk-shape stalk-root stalk-surface-above-ring stalk-surface-below-ring  \
# 100           e       <NA>                        s                        s
# ...

# %% [markdown]
# # 54
# Select first 5 rows and columns from start to odor using loc

# %%
df.iloc[:5, :6]
# Out:
#   cat cap-shape cap-surface cap-color bruises odor
# 0   e         b           f         g       f    n
# 1   e         b           f         g       f    n
# 2   e         b           f         g       f    n
# 3   e         b           f         g       f    n
# 4   e         b           f         g       f    n

# %% [markdown]
# # 55
# Select all rows and in terms of columns select all columns after ring-number using loc

# %%
df.iloc[:,18:]
# Out:
#      ring-number ring-type spore-print-color population habitat
# 0              t         p                 w          n       g
# 1              t         p                 w          s       g
# 2              t         p                 w          s       g
# 3              t         p                 w          n       g
# 4              t         p                 w          s       g
# ...          ...       ...               ...        ...     ...
# 8118           o         l                 h          v       g
# 8119           o         l                 h          y       p
# 8120           o         e                 w          v       d
# 8121           o         l                 h          v       d
# 8122           o         l                 h          y       g
#
# [8123 rows x 5 columns]

# %% [markdown]
# # 56
#
# Replace p with poisonous in cat column

# %%
df.replace('p', "poisonous", inplace=True)
df
# Out:
#             cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0             e         b           f         g       f    n               f
# 1             e         b           f         g       f    n               f
# 2             e         b           f         g       f    n               f
# 3             e         b           f         g       f    n               f
# 4             e         b           f         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8118  poisonous         x           y         y       f    f               f
# 8119  poisonous         x           y         y       f    f               f
# 8120  poisonous         x           y         y       f    n               f
# 8121  poisonous         x           y         y       f    f               f
# 8122  poisonous         x           y         y       f    f               f
#
# ...

# %% [markdown]
# # 57
# Replace e with edible in cat column

# %%
df.replace('e','edible', inplace= True)
df
# Out:
#             cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        edible         b           f         g       f    n               f
# 1        edible         b           f         g       f    n               f
# 2        edible         b           f         g       f    n               f
# 3        edible         b           f         g       f    n               f
# 4        edible         b           f         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8118  poisonous         x           y         y       f    f               f
# 8119  poisonous         x           y         y       f    f               f
# 8120  poisonous         x           y         y       f    n               f
# 8121  poisonous         x           y         y       f    f               f
# 8122  poisonous         x           y         y       f    f               f
#
# ...

# %% [markdown]
# # 58
# Create a new column called poisonous, with 0 where mushroom is edible and 1 where mushroom is poisonous

# %%
df['poisonous']=df['cat'].apply(lambda x: 1 if x== 'poisonous' else 0)
df
# Out:
#             cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        edible         b           f         g       f    n               f
# 1        edible         b           f         g       f    n               f
# 2        edible         b           f         g       f    n               f
# 3        edible         b           f         g       f    n               f
# 4        edible         b           f         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8118  poisonous         x           y         y       f    f               f
# 8119  poisonous         x           y         y       f    f               f
# 8120  poisonous         x           y         y       f    n               f
# 8121  poisonous         x           y         y       f    f               f
# 8122  poisonous         x           y         y       f    f               f
#
# ...

# %% [markdown]
# # 59
# Multiply poisinoious values with 1000 and store the results back in the dataframe

# %%
df['poisonous']=df['poisonous']*1000
df
# Out:
#             cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        edible         b           f         g       f    n               f
# 1        edible         b           f         g       f    n               f
# 2        edible         b           f         g       f    n               f
# 3        edible         b           f         g       f    n               f
# 4        edible         b           f         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8118  poisonous         x           y         y       f    f               f
# 8119  poisonous         x           y         y       f    f               f
# 8120  poisonous         x           y         y       f    n               f
# 8121  poisonous         x           y         y       f    f               f
# 8122  poisonous         x           y         y       f    f               f
#
# ...

# %% [markdown]
# # 60
# Delete the poisonous column and make the change permanent

# %%
df.drop('poisonous', axis=1, inplace=True)
df
# Out:
#             cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        edible         b           f         g       f    n               f
# 1        edible         b           f         g       f    n               f
# 2        edible         b           f         g       f    n               f
# 3        edible         b           f         g       f    n               f
# 4        edible         b           f         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8118  poisonous         x           y         y       f    f               f
# 8119  poisonous         x           y         y       f    f               f
# 8120  poisonous         x           y         y       f    n               f
# 8121  poisonous         x           y         y       f    f               f
# 8122  poisonous         x           y         y       f    f               f
#
# ...

# %% [markdown]
# # 61
# Transpose the whole dataframe (rotate the dataframe by 90 deg) and store the reslut in dfT vaiable

# %%
dfT = df.T
dfT
# Out:
#                                0          1          2          3     \
# cat                          edible     edible     edible     edible
# cap-shape                         b          b          b          b
# cap-surface                       f          f          f          f
# cap-color                         g          g          g          g
# bruises                           f          f          f          f
# odor                              n          n          n          n
# gill-attachment                   f          f          f          f
# gill-spacing                      w          w          w          w
# gill-size                         b          b          b          b
# gill-color                poisonous  poisonous          w  poisonous
# stalk-shape                  edible     edible     edible     edible
# stalk-root                     <NA>       <NA>       <NA>       <NA>
# stalk-surface-above-ring          k          s          s          k
# ...

# %% [markdown]
# # 62
# Transpose (rotate) dfT back into original df

# %%
df = dfT.T
df
# Out:
#             cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        edible         b           f         g       f    n               f
# 1        edible         b           f         g       f    n               f
# 2        edible         b           f         g       f    n               f
# 3        edible         b           f         g       f    n               f
# 4        edible         b           f         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8118  poisonous         x           y         y       f    f               f
# 8119  poisonous         x           y         y       f    f               f
# 8120  poisonous         x           y         y       f    n               f
# 8121  poisonous         x           y         y       f    f               f
# 8122  poisonous         x           y         y       f    f               f
#
# ...

# %% [markdown]
# # 63
# Draw a bar plot of the count of edible and poisonous mushroom counts

# %%
df['cat'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cat'>

# %% [markdown]
# # 64
# Draw a bar plot of the cap-color
#
# Note that brown=n, buff=b, cinnamon=c, gray=g, green=r, pink=p, purple=u, red=e, white=w, yellow=y

# %%
df['cap-color'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cap-color'>

# %% [markdown]
# # 65
# Draw a pie chart for the count of edible and poisonous mushrooms

# %%
df['cat'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 66
# Draw a pie chart for population values value count
#
# Note: abundant=a, clustered=c, numerous=n, scattered=s, several=v, solitary=y

# %%
df['population'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 67
# Convert the dataframe into a numpy array

# %%
df.to_numpy()
# Out:
# array([['edible', 'b', 'f', ..., 'w', 'n', 'g'],
#        ['edible', 'b', 'f', ..., 'w', 's', 'g'],
#        ['edible', 'b', 'f', ..., 'w', 's', 'g'],
#        ...,
#        ['poisonous', 'x', 'y', ..., 'w', 'v', 'd'],
#        ['poisonous', 'x', 'y', ..., 'h', 'v', 'd'],
#        ['poisonous', 'x', 'y', ..., 'h', 'y', 'g']], dtype=object)

# %% [markdown]
# # 68
# Put the cat column into y variable and the rest of the comlumns in X

# %%
X = df.iloc[:, 1:]
y = df['cat']

# %% [markdown]
# # 69
# Create a shallow copy of the dataframe

# %%
df_copy = df.copy(deep=False)
df_copy
# Out:
#             cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        edible         b           f         g       f    n               f
# 1        edible         b           f         g       f    n               f
# 2        edible         b           f         g       f    n               f
# 3        edible         b           f         g       f    n               f
# 4        edible         b           f         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8118  poisonous         x           y         y       f    f               f
# 8119  poisonous         x           y         y       f    f               f
# 8120  poisonous         x           y         y       f    n               f
# 8121  poisonous         x           y         y       f    f               f
# 8122  poisonous         x           y         y       f    f               f
#
# ...

# %% [markdown]
# # 70
# Create a deep copy of the dataframe

# %%
df_copy = df.copy()
df_copy
# Out:
#             cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        edible         b           f         g       f    n               f
# 1        edible         b           f         g       f    n               f
# 2        edible         b           f         g       f    n               f
# 3        edible         b           f         g       f    n               f
# 4        edible         b           f         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8118  poisonous         x           y         y       f    f               f
# 8119  poisonous         x           y         y       f    f               f
# 8120  poisonous         x           y         y       f    n               f
# 8121  poisonous         x           y         y       f    f               f
# 8122  poisonous         x           y         y       f    f               f
#
# ...

# %% [markdown]
# # 71
# Delete the last 5 columns from the df permanently

# %%
df.drop(df.columns[-5:], axis =1, inplace=True)
df
# Out:
#             cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        edible         b           f         g       f    n               f
# 1        edible         b           f         g       f    n               f
# 2        edible         b           f         g       f    n               f
# 3        edible         b           f         g       f    n               f
# 4        edible         b           f         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8118  poisonous         x           y         y       f    f               f
# 8119  poisonous         x           y         y       f    f               f
# 8120  poisonous         x           y         y       f    n               f
# 8121  poisonous         x           y         y       f    f               f
# 8122  poisonous         x           y         y       f    f               f
#
# ...

# %% [markdown]
# # 72
# Drop the last 8100 rows and make this change permanent

# %%
df.drop(df.index[-8100:], inplace=True)
df
# Out:
#        cat cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0   edible         b           f         g       f    n               f
# 1   edible         b           f         g       f    n               f
# 2   edible         b           f         g       f    n               f
# 3   edible         b           f         g       f    n               f
# 4   edible         b           f         g       f    n               f
# 5   edible         b           f         g       f    n               f
# 6   edible         b           f         g       f    n               f
# 7   edible         b           f         g       f    n               f
# 8   edible         b           f         g       f    n               f
# 9   edible         b           f         g       f    n               f
# 10  edible         b           f         g       f    n               f
# 11  edible         b           f         g       f    n               f
# ...

# %% [markdown]
# # 73
# Save the final dataframe to a file called mushroom_final.csv

# %%
df.to_csv('mushroom_final_csv')
